# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jamieleeuw/FlyrankAI/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# I chose Lane 2: Refresh / Content Opportunity Scoring.
#
# I want to identify which content pages show signs of decline
# and should be prioritized for review first, based on observable
# signals like impressions, CTR, content age, and trend direction.
#
# I chose this lane because it aligns with my current skills in
# data analysis and machine learning, and it produces a clear,
# actionable output — a ranked list of pages a content team can
# actually use.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# Running cells with 'Python 3.14.5' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/Japan/AppData/Local/Programs/Python/Python314/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# Question: Which content pages are most likely declining and
# should be reviewed first for a content refresh?
#
# Decision: Which pages does a content editor open and review
# this week out of hundreds of candidates?
#
# Action: A content editor reviews the top-ranked page and
# decides whether to refresh, expand, rewrite, or leave it.
#
# Cost of being wrong: If the model ranks the wrong pages first,
# the team wastes limited review time on pages that don't need
# attention while truly declining pages continue losing visibility
# and traffic unnoticed.
#
# Why ML can help: There are too many pages to review manually.
# A model that learns from signals like impressions, CTR, age,
# and trend direction can rank candidates faster and more
# consistently than a human scanning a spreadsheet.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv('../../data/raw/content_refresh_anonymized.csv')

print("Shape:", df.shape)
print("\nTrend direction counts:")
print(df['trend_direction'].value_counts())
print("\nImpressions 90d summary:")
print(df['impressions_90d'].describe())
print("\nContent age summary:")
print(df['content_age_days'].describe())

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# What I can claim:
# - I can observe which pages currently show declining trend signals
# - I can rank pages by their likelihood of needing review based
#   on observable signals
# - I can show that a learned model beats a simple rule baseline
#
# What I cannot claim:
# - I cannot prove that refreshing a page will cause it to recover
# - I cannot prove causation — only association between signals
#   and outcomes
# - I cannot claim these results represent all content on the internet
#
# This model is a decision-support tool. It helps a human reviewer
# prioritize their limited time — it does not replace human judgment.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# 1. Every section filled — you just filled them all in ✅
# 2. Run the notebook top to bottom — in VS Code press Run All at the top of the notebook. Tell me if any errors come up.
# 3. No private data — the starter dataset is already anonymized so you're fine ✅
# 4. Careful words — your Section 4 uses "observe", "cannot prove", "decision-support" ✅
# 5. Commit and push — once the notebook runs clean, run:
